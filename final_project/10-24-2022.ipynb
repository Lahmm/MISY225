# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import streamlit as st

# %%
df = pd.read_csv('worldcities.csv')

# %%
df[df.capital.isin(['primary', 'admin'])]
# Out:
#               city     city_ascii      lat       lon      country iso2 iso3  \
# 0            Tokyo          Tokyo  35.6897  139.6922        Japan   JP  JPN
# 1          Jakarta        Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi          Delhi  28.6600   77.2300        India   IN  IND
# 3           Mumbai         Mumbai  18.9667   72.8333        India   IN  IND
# 4           Manila         Manila  14.6000  120.9833  Philippines   PH  PHL
# ..             ...            ...      ...       ...          ...  ...  ...
# 713         Raipur         Raipur  21.2379   81.6337        India   IN  IND
# 715       Arequipa       Arequipa -16.3988  -71.5369         Peru   PE  PER
# 716  Port Harcourt  Port Harcourt   4.7500    7.0000      Nigeria   NG  NGA
# 720         Dnipro         Dnipro  48.4500   34.9833      Ukraine   UA  UKR
# 722         Quetta         Quetta  30.1920   67.0070     Pakistan   PK  PAK
#
# ...
